# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# Load CSVs
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(train_df.head())
print(f"Train size: {len(train_df)}, Test size: {len(test_df)}")

# Load a sample image
sample_id = train_df.iloc[0]["Id"]
sample_label = train_df.iloc[0]["Category"]
img_path = Path(f"train/train/{sample_label}/{sample_id}.png")
# Out:
#       Id  Category
# 0   7168         6
# 1   9876         3
# 2  78117         6
# 3   9626         1
# 4  29492         3
# Train size: 17000, Test size: 3000

# %%
# view original image
img = Image.open(img_path)
plt.imshow(img)
plt.title(f"ID: {sample_id}, Label: {sample_label}")
plt.show()

# %%
# convert to grayscale
# function from lab 3
def show_images(images, titles, cmap=None):
    n = len(images)
    plt.figure(figsize=(5*n, 5))
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(images[i], cmap='gray', vmin=0, vmax=255)
        plt.title(titles[i])
        plt.axis('off')
    plt.show()

# Pick one image from class 0
img_path = "train/train/0/103265.png"
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

show_images([gray], ["Grayscale"])

# %%
# train images to grayscale
# import pandas as pd
# import numpy as np

# train_df = pd.read_csv("train.csv")

# images = []
# labels = []

# for _, row in train_df.iterrows():
#     img_id = row["Id"]
#     label = row["Category"]
#     path = f"train/train/{label}/{img_id}.png"
    
#     img = cv2.imread(path)
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     images.append(gray)
#     labels.append(label)

# images = np.array(images)
# labels = np.array(labels)

# print(f"Loaded {len(images)} images, shape: {images.shape}")

# %%
# # save grayscale images locally
# from pathlib import Path

# output_dir = Path("train_gray")
# output_dir.mkdir(exist_ok=True)

# for _, row in train_df.iterrows():
#     img_id = row["Id"]
#     label = row["Category"]
#     path = f"train/train/{label}/{img_id}.png"
    
#     img = cv2.imread(path)
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     cv2.imwrite(str(output_dir / f"{img_id}.png"), gray)

# print("Done saving grayscale images")

# %%
# read in grayscale images
train_df = pd.read_csv("train.csv")

images = np.array([
    cv2.imread(f"train_gray/{row['Id']}.png", cv2.IMREAD_GRAYSCALE)
    for _, row in tqdm(train_df.iterrows(), total=len(train_df))
])
labels = train_df["Category"].values

print(f"Loaded {len(images)} images, shape: {images.shape}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 17000/17000 [00:03<00:00, 4576.29it/s]
# Loaded 17000 images, shape: (17000, 32, 32)

# %%
# train val split:
from sklearn.model_selection import train_test_split
# Flatten images: (N, 32, 32) -> (N, 1024)
X = images.reshape(len(images), -1) / 255.0  # normalize to 0-1
y = labels

# reshuffle and split into train and validation
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=75, stratify=y)

# %%
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# ViT hyperparameters
patch_size = 4        # 32/4 = 8x8 = 64 patches
num_patches = (32 // patch_size) ** 2  # 64
projection_dim = 64
num_heads = 4
transformer_layers = 4
mlp_dim = 128

def mlp_block(x, dim):
    x = layers.Dense(dim, activation="relu")(x)
    x = layers.Dense(projection_dim)(x)
    return x

def transformer_block(x):
    # Self-attention
    attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)(x, x)
    x = layers.Add()([x, attn])
    x = layers.LayerNormalization()(x)
    # MLP
    mlp = mlp_block(x, mlp_dim)
    x = layers.Add()([x, mlp])
    x = layers.LayerNormalization()(x)
    return x

# Build ViT
inputs = keras.Input(shape=(1024,))  # flattened 32x32

# Split into patches
patches = layers.Reshape((num_patches, patch_size * patch_size))(inputs)

# Project patches
x = layers.Dense(projection_dim)(patches)

# Add positional embedding
positions = tf.range(start=0, limit=num_patches, delta=1)
pos_embed = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)(positions)
x = x + pos_embed

# Transformer blocks
for _ in range(transformer_layers):
    x = transformer_block(x)

# Classification head
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dense(64, activation="relu")(x)
outputs = layers.Dense(10, activation="softmax")(x)

vit_model = keras.Model(inputs, outputs)
vit_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
vit_model.summary()

# Train
import tensorflow as tf
history_vit = vit_model.fit(
    X_train, y_train,
    epochs=20,
    validation_data=(X_val, y_val),
    verbose=1
)

print(f"ViT val_accuracy: {max(history_vit.history['val_accuracy']):.4f}")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 1024)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_2 (Reshape)           │ (None, 64, 16)            │               0 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 64, 64)            │           1,088 │ reshape_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_9 (Add)                   │ (None, 64, 64)            │               0 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_4        │ (None, 64, 64)            │          66,368 │ add_9[0][0], add_9[0][0]   │
# │ (MultiHeadAttention)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_10 (Add)                  │ (None, 64, 64)            │               0 │ add_9[0][0],               │
# │                               │                           │                 │ multi_head_attention_4[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_8         │ (None, 64, 64)            │             128 │ add_10[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 64, 128)           │           8,320 │ layer_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_14 (Dense)              │ (None, 64, 64)            │           8,256 │ dense_13[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_11 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_8[0][… │
# │                               │                           │                 │ dense_14[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_9         │ (None, 64, 64)            │             128 │ add_11[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_5        │ (None, 64, 64)            │          66,368 │ layer_normalization_9[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_12 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_9[0][… │
# │                               │                           │                 │ multi_head_attention_5[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_10        │ (None, 64, 64)            │             128 │ add_12[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_15 (Dense)              │ (None, 64, 128)           │           8,320 │ layer_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_16 (Dense)              │ (None, 64, 64)            │           8,256 │ dense_15[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_13 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_10[0]… │
# │                               │                           │                 │ dense_16[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_11        │ (None, 64, 64)            │             128 │ add_13[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_6        │ (None, 64, 64)            │          66,368 │ layer_normalization_11[0]… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_14 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_11[0]… │
# │                               │                           │                 │ multi_head_attention_6[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_12        │ (None, 64, 64)            │             128 │ add_14[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_17 (Dense)              │ (None, 64, 128)           │           8,320 │ layer_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_18 (Dense)              │ (None, 64, 64)            │           8,256 │ dense_17[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_15 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_12[0]… │
# │                               │                           │                 │ dense_18[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_13        │ (None, 64, 64)            │             128 │ add_15[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_7        │ (None, 64, 64)            │          66,368 │ layer_normalization_13[0]… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_16 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_13[0]… │
# │                               │                           │                 │ multi_head_attention_7[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_14        │ (None, 64, 64)            │             128 │ add_16[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_19 (Dense)              │ (None, 64, 128)           │           8,320 │ layer_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_20 (Dense)              │ (None, 64, 64)            │           8,256 │ dense_19[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_17 (Add)                  │ (None, 64, 64)            │               0 │ layer_normalization_14[0]… │
# │                               │                           │                 │ dense_20[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_15        │ (None, 64, 64)            │             128 │ add_17[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d_1    │ (None, 64)                │               0 │ layer_normalization_15[0]… │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_21 (Dense)              │ (None, 64)                │           4,160 │ global_average_pooling1d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_22 (Dense)              │ (None, 10)                │             650 │ dense_21[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 338,698 (1.29 MB)
#  Trainable params: 338,698 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.5140 - loss: 1.3706 - val_accuracy: 0.6099 - val_loss: 1.0448
# Epoch 2/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 27s 67ms/step - accuracy: 0.6997 - loss: 0.8459 - val_accuracy: 0.7581 - val_loss: 0.6890
# Epoch 3/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.7731 - loss: 0.6287 - val_accuracy: 0.8005 - val_loss: 0.5976
# Epoch 4/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 27s 67ms/step - accuracy: 0.8229 - loss: 0.4982 - val_accuracy: 0.8426 - val_loss: 0.4749
# Epoch 5/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.8522 - loss: 0.4115 - val_accuracy: 0.8579 - val_loss: 0.4071
# Epoch 6/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.8738 - loss: 0.3660 - val_accuracy: 0.8960 - val_loss: 0.3208
# Epoch 7/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.8998 - loss: 0.2872 - val_accuracy: 0.8927 - val_loss: 0.3182
# Epoch 8/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9092 - loss: 0.2634 - val_accuracy: 0.9101 - val_loss: 0.2771
# Epoch 9/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.9205 - loss: 0.2343 - val_accuracy: 0.9132 - val_loss: 0.2613
# Epoch 10/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9322 - loss: 0.2020 - val_accuracy: 0.9019 - val_loss: 0.2972
# Epoch 11/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.9274 - loss: 0.2107 - val_accuracy: 0.9179 - val_loss: 0.2517
# Epoch 12/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 64ms/step - accuracy: 0.9355 - loss: 0.1813 - val_accuracy: 0.9064 - val_loss: 0.2835
# Epoch 13/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 64ms/step - accuracy: 0.9460 - loss: 0.1607 - val_accuracy: 0.9235 - val_loss: 0.2181
# Epoch 14/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.9482 - loss: 0.1482 - val_accuracy: 0.9400 - val_loss: 0.1899
# Epoch 15/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9493 - loss: 0.1462 - val_accuracy: 0.9252 - val_loss: 0.2213
# Epoch 16/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9461 - loss: 0.1575 - val_accuracy: 0.9412 - val_loss: 0.1880
# Epoch 17/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 30s 75ms/step - accuracy: 0.9555 - loss: 0.1323 - val_accuracy: 0.9584 - val_loss: 0.1487
# Epoch 18/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9551 - loss: 0.1266 - val_accuracy: 0.9482 - val_loss: 0.1601
# Epoch 19/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 62ms/step - accuracy: 0.9578 - loss: 0.1212 - val_accuracy: 0.9280 - val_loss: 0.2140
# Epoch 20/20
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.9547 - loss: 0.1291 - val_accuracy: 0.9496 - val_loss: 0.1517
# ViT val_accuracy: 0.9584

# %%
# 1. Check class distribution
unique, counts = np.unique(y, return_counts=True)
print(dict(zip(unique, counts)))

# 2. Plot confusion matrix to see where it's making mistakes
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = np.argmax(best_model.predict(X_val), axis=1)

cm = confusion_matrix(y_val, y_pred)
ConfusionMatrixDisplay(cm).plot()
# Out:
# {np.int64(0): np.int64(1700), np.int64(1): np.int64(1700), np.int64(2): np.int64(1700), np.int64(3): np.int64(1700), np.int64(4): np.int64(1700), np.int64(5): np.int64(1700), np.int64(6): np.int64(1700), np.int64(7): np.int64(1700), np.int64(8): np.int64(1700), np.int64(9): np.int64(1700)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 # 2. Plot confusion matrix to see where it's making mistakes
#       6 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# ----> 8 y_pred = np.argmax(best_model.predict(X_val), axis=1)
#      10 cm = confusion_matrix(y_val, y_pred)
#      11 ConfusionMatrixDisplay(cm).plot()
#
# NameError: name 'best_model' is not defined
